# %%
import pandas as pd

# %%
df = pd.read_csv("Car_Sales.csv")

# %%
df.head()
# Out:
#   Manufacturer    Model Power Perf Factor  Unit Sales    Price  \
# 0        Acura  Integra       58.28014952       16919  $21,500
# 1        Acura       TL       91.37077766       39384  $28,400
# 2        Acura       RL       91.38977933        8588  $42,000
# 3         Audi       A4        62.7776392       20397  $23,990
# 4         Audi       A6       84.56510502       18780  $33,950
#
#   Year Resale Value Retention % Retention Value  Engine Size Horsepower  \
# 0           $16,360         76%            GOOD          1.8        140
# 1           $19,875         70%            GOOD          3.2        225
# 2           $29,725         71%            GOOD          3.5        210
# 3           $22,255         93%            GOOD          1.8        150
# 4           $23,555         69%            GOOD          2.8        200
#
#   Vehicle_type  Fuel Efficiency  Wheelbase  Width  Length Curb Weight  \
# 0    Passenger             28.0      101.2   67.3   172.4       2.639
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Manufacturer       155 non-null    object
#  1   Model              155 non-null    object
#  2   Power Perf Factor  155 non-null    object
#  3   Unit Sales         155 non-null    int64
#  4   Price              154 non-null    object
#  5   Year Resale Value  153 non-null    object
#  6   Retention %        155 non-null    object
#  7   Retention Value    154 non-null    object
#  8   Engine Size        153 non-null    float64
#  9   Horsepower         154 non-null    object
#  10  Vehicle_type       153 non-null    object
#  11  Fuel Efficiency    154 non-null    float64
#  12  Wheelbase          155 non-null    float64
#  13  Width              153 non-null    float64
#  14  Length             154 non-null    float64
#  15  Curb Weight        155 non-null    object
# ...

# %%
df.describe()
# Out:
#           Unit Sales  Engine Size  Fuel Efficiency   Wheelbase       Width  \
# count     155.000000   153.000000       154.000000  155.000000  153.000000
# mean    53245.832258     3.065359        23.824675  107.490968   71.188889
# std     68397.550373     1.053648         4.279657    7.665925    3.471473
# min       110.000000     1.000000        15.000000   92.600000   62.600000
# 25%     14074.500000     2.300000        21.000000  103.000000   68.400000
# 50%     29450.000000     3.000000        24.000000  107.000000   70.600000
# 75%     68183.500000     3.800000        26.000000  112.200000   73.500000
# max    540561.000000     8.000000        45.000000  138.700000   79.900000
#
#            Length
# count  154.000000
# mean   187.382468
# std     13.486537
# min    149.400000
# 25%    177.700000
# 50%    187.900000
# 75%    196.175000
# max    224.500000

# %%
df.isnull().sum()
# Out:
# Manufacturer         0
# Model                0
# Power Perf Factor    0
# Unit Sales           0
# Price                1
# Year Resale Value    2
# Retention %          0
# Retention Value      1
# Engine Size          2
# Horsepower           1
# Vehicle_type         2
# Fuel Efficiency      1
# Wheelbase            0
# Width                2
# Length               1
# Curb Weight          0
# Fuel Capacity        0
# Latest Launch        1
# dtype: int64

# %%
df.shape
# Out:
# (155, 18)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Power Perf Factor', 'Unit Sales', 'Price',
#        'Year Resale Value', 'Retention %', 'Retention Value', 'Engine Size',
#        'Horsepower', 'Vehicle_type', 'Fuel Efficiency', 'Wheelbase', 'Width',
#        'Length', 'Curb Weight', 'Fuel Capacity', 'Latest Launch'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Manufacturer         0
# Model                0
# Power Perf Factor    0
# Unit Sales           0
# Price                1
# Year Resale Value    2
# Retention %          0
# Retention Value      1
# Engine Size          2
# Horsepower           1
# Vehicle_type         2
# Fuel Efficiency      1
# Wheelbase            0
# Width                2
# Length               1
# Curb Weight          0
# Fuel Capacity        0
# Latest Launch        1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Manufacturer       155 non-null    object
#  1   Model              155 non-null    object
#  2   Power Perf Factor  155 non-null    object
#  3   Unit Sales         155 non-null    int64
#  4   Price              154 non-null    object
#  5   Year Resale Value  153 non-null    object
#  6   Retention %        155 non-null    object
#  7   Retention Value    154 non-null    object
#  8   Engine Size        153 non-null    float64
#  9   Horsepower         154 non-null    object
#  10  Vehicle_type       153 non-null    object
#  11  Fuel Efficiency    154 non-null    float64
#  12  Wheelbase          155 non-null    float64
#  13  Width              153 non-null    float64
#  14  Length             154 non-null    float64
#  15  Curb Weight        155 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#           Unit Sales  Engine Size  Fuel Efficiency   Wheelbase       Width  \
# count     155.000000   153.000000       154.000000  155.000000  153.000000
# mean    53245.832258     3.065359        23.824675  107.490968   71.188889
# std     68397.550373     1.053648         4.279657    7.665925    3.471473
# min       110.000000     1.000000        15.000000   92.600000   62.600000
# 25%     14074.500000     2.300000        21.000000  103.000000   68.400000
# 50%     29450.000000     3.000000        24.000000  107.000000   70.600000
# 75%     68183.500000     3.800000        26.000000  112.200000   73.500000
# max    540561.000000     8.000000        45.000000  138.700000   79.900000
#
#            Length
# count  154.000000
# mean   187.382468
# std     13.486537
# min    149.400000
# 25%    177.700000
# 50%    187.900000
# 75%    196.175000
# max    224.500000

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Power Perf Factor', 'Unit Sales', 'Price',
#        'Year Resale Value', 'Retention %', 'Retention Value', 'Engine Size',
#        'Horsepower', 'Vehicle_type', 'Fuel Efficiency', 'Wheelbase', 'Width',
#        'Length', 'Curb Weight', 'Fuel Capacity', 'Latest Launch'],
#       dtype='object')

# %%
df.head()
# Out:
#   Manufacturer    Model Power Perf Factor  Unit Sales    Price  \
# 0        Acura  Integra       58.28014952       16919  $21,500
# 1        Acura       TL       91.37077766       39384  $28,400
# 2        Acura       RL       91.38977933        8588  $42,000
# 3         Audi       A4        62.7776392       20397  $23,990
# 4         Audi       A6       84.56510502       18780  $33,950
#
#   Year Resale Value Retention % Retention Value  Engine Size Horsepower  \
# 0           $16,360         76%            GOOD          1.8        140
# 1           $19,875         70%            GOOD          3.2        225
# 2           $29,725         71%            GOOD          3.5        210
# 3           $22,255         93%            GOOD          1.8        150
# 4           $23,555         69%            GOOD          2.8        200
#
#   Vehicle_type  Fuel Efficiency  Wheelbase  Width  Length Curb Weight  \
# 0    Passenger             28.0      101.2   67.3   172.4       2.639
# ...

# %%
df['Manufacturer'].apply(type).value_counts()
# Out:
# Manufacturer
# <class 'str'>    155
# Name: count, dtype: int64

# %%
df['Manufacturer'] = df['Manufacturer'].fillna('Unknown')

# %%
df['Manufacturer'].value_counts()
# Out:
# Manufacturer
# Ford          11
# Dodge         11
# Chevrolet      9
# Mercedes-B     9
# Toyota         9
# Nissan         7
# Mitsubishi     7
# Pontiac        6
# Mercury        6
# Oldsmobile     6
# Lexus          6
# Chrysler       6
# Volvo          6
# Volkswagen     6
# Cadillac       5
# Honda          5
# Saturn         5
# Plymouth       4
# Buick          4
# Audi           3
# BMW            3
# Acura          3
# Lincoln        3
# Porsche        3
# Jeep           3
# Hyundai        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: count, dtype: int64

# %%
df['Price'] = pd.to_numeric(df['Price'],
errors='coerce')

# %%
df['Price'].isnull().sum()
# Out:
# np.int64(155)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['Price']. dropna(), bins=10)

plt.title("car Price Distribution")
plt.xlabel("Price")
plt.ylabel("Number of Cars")
plt.show()

# %%
import pandas as pd

# %%
df['Horsepower'].head()
# Out:
# 0    140
# 1    225
# 2    210
# 3    150
# 4    200
# Name: Horsepower, dtype: object

# %%
df['Horsepower'] = pd.to_numeric(df['Horsepower'],
errors='coerce')

# %%
df['Horsepower'].dtype
# Out:
# dtype('float64')

# %%
df['Horsepower'].isnull().sum()
# Out:
# np.int64(2)

# %%
data = df[['Horsepower', 'Price']].dropna()

# %%
plt.figure(figsize=(8,5))

plt.scatter(data['Horsepower'], data['Price'])
plt.title("Price vs Horsepower")
plt.xlabel("Horsepower")
plt.ylabel("Price")

plt.show()

# %%
id="7p3m5d"
data[['Horsepower', 'Price']].head()
# Out:
# Empty DataFrame
# Columns: [Horsepower, Price]
# Index: []

# %%
id="m9z2aa"
data[['Horsepower', 'Price']].dtypes
# Out:
# Horsepower    float64
# Price         float64
# dtype: object

# %%
id="q8k1vf"
data[['Horsepower', 'Price']].describe()
# Out:
#        Horsepower  Price
# count         0.0    0.0
# mean          NaN    NaN
# std           NaN    NaN
# min           NaN    NaN
# 25%           NaN    NaN
# 50%           NaN    NaN
# 75%           NaN    NaN
# max           NaN    NaN

# %%
df['Horsepower'] = pd.to_numeric(df['Horsepower'],
errors='coerce')

# %%
df['Price'] = pd.to_numeric(df['Price'],
errors='coerce')

# %%
data = df[['Horsepower', 'Price']].dropna()

# %%
data.shape
# Out:
# (0, 2)

# %%
data.corr()
# Out:
#             Horsepower  Price
# Horsepower         NaN    NaN
# Price              NaN    NaN

# %%
df[['Horsepower', 'Price']].head(10)
# Out:
#    Horsepower  Price
# 0       140.0    NaN
# 1       225.0    NaN
# 2       210.0    NaN
# 3       150.0    NaN
# 4       200.0    NaN
# 5       310.0    NaN
# 6       170.0    NaN
# 7       193.0    NaN
# 8       193.0    NaN
# 9       175.0    NaN

# %%
df['Horsepower'].unique()[:10]
# Out:
# array([140., 225., 210., 150., 200., 310., 170., 193., 175., 240.])

# %%
data[['Horsepower', 'Price']].corr()
# Out:
#             Horsepower  Price
# Horsepower         NaN    NaN
# Price              NaN    NaN

# %%
df.head()
# Out:
#   Manufacturer    Model Power Perf Factor  Unit Sales  Price  \
# 0        Acura  Integra       58.28014952       16919    NaN
# 1        Acura       TL       91.37077766       39384    NaN
# 2        Acura       RL       91.38977933        8588    NaN
# 3         Audi       A4        62.7776392       20397    NaN
# 4         Audi       A6       84.56510502       18780    NaN
#
#   Year Resale Value Retention % Retention Value  Engine Size  Horsepower  \
# 0           $16,360         76%            GOOD          1.8       140.0
# 1           $19,875         70%            GOOD          3.2       225.0
# 2           $29,725         71%            GOOD          3.5       210.0
# 3           $22,255         93%            GOOD          1.8       150.0
# 4           $23,555         69%            GOOD          2.8       200.0
#
#   Vehicle_type  Fuel Efficiency  Wheelbase  Width  Length Curb Weight  \
# 0    Passenger             28.0      101.2   67.3   172.4       2.639
# ...

# %%
df['Price'].head(10)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: Price, dtype: float64

# %%
df['Price'].isnull().sum()
# Out:
# np.int64(155)

# %%
df['Price'] = df['Price'].str.replace('$','').str.replace(',','')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df['Price'] = df['Price'].str.replace('$','').str.replace(',','')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
df['Price'] = pd.to_numeric(df['Price'],
errors='coerce')

# %%
df['Price'].dtype

# %%
data = df[['Horsepower','Price']].dropna()

# %%
data.shape

# %%
data = data.replace('Null', pd.NA)

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (152, 2)

# %%
data.corr()
# Out:
#             Horsepower     Price
# Horsepower    1.000000  0.851323
# Price         0.851323  1.000000

# %%
df[['Manufacturer', 'Model', 'Price']].sort_values(by='Price', ascending=False).head(10)
# Out:
#     Manufacturer           Model    Price
# 97    Mercedes-B           CL500  85500.0
# 93    Mercedes-B        SL-Class  82600.0
# 124      Porsche  Carrera Cabrio  74970.0
# 123      Porsche   Carrera Coupe  71020.0
# 37         Dodge           Viper  69725.0
# 92    Mercedes-B         S-Class  69700.0
# 5           Audi              A8  62000.0
# 72         Lexus           LX470  60105.0
# 23     Chevrolet        Corvette  55705.0
# 71         Lexus           LS400  54005.0

# %%
type(df['Price'])
# Out:
# pandas.core.series.Series

# %%
avg_price = df.groupby('Manufacturer').agg({'Price':'mean'}).sort_values(by='Price', ascending=False).head(10)

# %%
avg_price
# Out:
#               Price
# Manufacturer
# Acura           NaN
# Audi            NaN
# BMW             NaN
# Buick           NaN
# Cadillac        NaN
# Chevrolet       NaN
# Chrysler        NaN
# Dodge           NaN
# Ford            NaN
# Honda           NaN

# %%
print(avg_price)
# Out:
#               Price
# Manufacturer
# Acura           NaN
# Audi            NaN
# BMW             NaN
# Buick           NaN
# Cadillac        NaN
# Chevrolet       NaN
# Chrysler        NaN
# Dodge           NaN
# Ford            NaN
# Honda           NaN

# %%
plt.figure(figsize=(10,5))
avg_price.plot(kind='bar')
plt.title("Top 10 Munufacturers by Average Price")
plt.xlabel("Manufactures")
plt.ylabel("Average Price")
plt.xticks(rotation=45)
plt.show()
